# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
import math

# %%
# Source of dataset: http://archive.ics.uci.edu/ml/datasets/Bank+Marketing

df = pd.read_csv('bank-additional-full.csv', sep=';')
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Attribute Information:
#
# see <a href="http://archive.ics.uci.edu/ml/datasets/Bank+Marketing" target="_blank">here</a>

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
# duration should not be included as that was unknown before contact complete
df_features = df[['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
       'contact', 'month', 'day_of_week','campaign', 'pdays',
       'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m', 'nr.employed']]

# %%
df_labels = df[['y']]

# %%
sns.countplot(df['y'])

# %%
plt.figure(figsize=(20, 50))

nrows = math.ceil(len(df_features.columns) / 3)
ncols = 3
categorical_features = []

for i, col in enumerate(df_features.columns):
    try:
        position = i + 1
        plt.subplot(nrows, ncols, position)
        sns.distplot(df[col])
    except TypeError:
        categorical_features.append(col)
        sns.countplot(x=col, hue='y', data=df)
# Out:
# c:\users\richard.ng\desktop\python36\lib\site-packages\matplotlib\axes\_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
def pdays_value_convert(x):
    if x == 999:
        return -1
    else:
        return x

df_features['pdays'] = df_features['pdays'].apply(pdays_value_convert)
# Out:
# c:\users\richard.ng\desktop\python36\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %% [markdown]
# ### Data preprocessing

# %%
categorical_features
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome']

# %%
df_features = pd.concat([df_features.drop(categorical_features, axis=1), pd.get_dummies(df_features[categorical_features], drop_first=True)], axis=1)

# %%
len(df_features[df_features['pdays'] == -1]) / len(df_features)
# Out:
# 0.9632174419733903

# %%
df_labels = pd.get_dummies(df_labels)[['y_yes']].rename(columns={'y_yes':'y'})

# %% [markdown]
# ### Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(df_features, df_labels, test_size=0.33, random_state=0)

# %% [markdown]
# ### Normalize data

# %%
numerical_features = [feat for feat in df.columns if feat not in categorical_features and feat != 'y' and feat != 'duration']

X_mean = X_train[numerical_features].mean(axis=0)
X_std = X_train[numerical_features].std(axis=0)

# %%
X_train[numerical_features] = (X_train[numerical_features] - X_mean) / X_std
# Out:
# c:\users\richard.ng\desktop\python36\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
X_test[numerical_features] = (X_test[numerical_features] - X_mean) / X_std
# Out:
# c:\users\richard.ng\desktop\python36\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %% [markdown]
# ### Train-validation split, then train the model

# %%
X_train = X_train.sample(frac=1).reset_index(drop=True)
y_train = y_train.sample(frac=1).reset_index(drop=True)

validation_samples = int(len(X_train) * 0.33)

X_val = X_train[:validation_samples]
y_val = y_train[:validation_samples]
partial_X_train = X_train[validation_samples:]
partial_y_train = y_train[validation_samples:]

# %%
def train_and_eval(classifier, epoch=None):
    classifier.fit(partial_X_train, partial_y_train.values.flatten())
    
    y_pred_val = classifier.predict(X_val)
    print(pd.crosstab(y_val.values.flatten(), y_pred_val, rownames=['True'], colnames=['Predicted'], margins=True))
    print('precision_recall_fscore: ' + str(precision_recall_fscore_support(y_val.values.flatten(), y_pred_val, average='weighted')))
    print('')
    print('\n')

print('DecisionTreeClassifier')
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
train_and_eval(classifier)

print('naive_bayes')
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
train_and_eval(classifier)

print('kernel svm')
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
train_and_eval(classifier)

print('RandomForestClassifier')
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
train_and_eval(classifier)
# Out:
# DecisionTreeClassifier
# Predicted     0     1   All
# True
# 0          6968  1088  8056
# 1           930   120  1050
# All        7898  1208  9106
# precision_recall_fscore: (0.7919723177804097, 0.7783878761256314, 0.7850439913163622, None)
#
#
#
# naive_bayes
# Predicted     0    1   All
# True
# 0          7506  550  8056
# 1           983   67  1050
# All        8489  617  9106
# precision_recall_fscore: (0.794768231117752, 0.8316494618932572, 0.8119880549275559, None)
#
#
#
# kernel svm
# Predicted     0   All
# True
# 0          8056  8056
# 1          1050  1050
# All        9106  9106
# precision_recall_fscore: (0.7826788949189064, 0.8846914122556556, 0.8305645049681345, None)
#
#
#
# RandomForestClassifier
# c:\users\richard.ng\desktop\python36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Predicted     0    1   All
# True
# 0          7945  111  8056
# 1          1033   17  1050
# All        8978  128  9106
# precision_recall_fscore: (0.7982140954978314, 0.8743685482099715, 0.8286038073377948, None)
